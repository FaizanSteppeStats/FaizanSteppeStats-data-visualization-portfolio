# %% [markdown]
# # Streaming Content Analytics Dashboard
#
# Portfolio project by Faizan Ahmed Janjua.

# %%
import pandas as pd

df = pd.read_csv('../data/streaming_content_data.csv')
df.head()

# %%
df.groupby('platform')['views'].sum().sort_values(ascending=False)

# %%
(df.groupby('platform')['completion_rate'].mean()*100).round(2)
