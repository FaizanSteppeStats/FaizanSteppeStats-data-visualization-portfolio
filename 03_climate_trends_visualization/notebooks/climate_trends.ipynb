# %% [markdown]
# # Climate Trends Visualization
#
# Portfolio project by Faizan Ahmed Janjua.

# %%
import pandas as pd

df = pd.read_csv('../data/climate_data.csv')
df.head()

# %%
df.groupby('city')['temperature_c'].mean().sort_values(ascending=False).round(2)

# %%
df.groupby('city')['rainfall_mm'].sum().sort_values(ascending=False).round(2)
