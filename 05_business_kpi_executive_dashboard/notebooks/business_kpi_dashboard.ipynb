# %% [markdown]
# # Business KPI Executive Dashboard
#
# Portfolio project by Faizan Ahmed Janjua.

# %%
import pandas as pd

df = pd.read_csv('../data/business_kpis.csv')
df.head()

# %%
df[['revenue','orders','conversion_rate_percent','retention_rate_percent']].describe().round(2)
