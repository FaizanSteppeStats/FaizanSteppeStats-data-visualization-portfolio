# %% [markdown]
# # Portugal Housing & Rent Dashboard
#
# Portfolio project by Faizan Ahmed Janjua.

# %%
import pandas as pd

df = pd.read_csv('../data/portugal_rent_data.csv')
df.head()

# %%
df.groupby('city')['rent_eur'].mean().sort_values(ascending=False).round(2)

# %%
df.groupby('bedrooms')['rent_eur'].mean().round(2)
